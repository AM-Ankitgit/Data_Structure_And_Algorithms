# %%
# What is efficiency in programming
1.time efficiency
2.and space or storage (memory)

# %% [markdown]
# # Time Complexity
# ![image.png](attachment:image.png)

# %% [markdown]
# # Measuring Time
# ![image.png](attachment:image.png)

# %% [markdown]
# # Counting Operation:
# - count number of operation  in program
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # order of growth
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### HOW TO CALCULATED TIME COMPLEXITY using  ORDER OF GROWTH
#
# USING big oh or O()
#
# ![image.png](attachment:image.png)
#
# if we have nested for loop the we count the number of operation in second loop
#
# for i in rang(10):
#     for i in rang(5): # here we only count operation from second loop
#         print(i) # this one operation

# %%
def fact_iter(n):
    ans =1 # operation 1
    while n>1: # operation 1
        ans *=n  # operation 2,3
        n-=1  # # operation 4,5
    return ans

n=10
fact_iter(n)
# total_operation = 1 + 5n  # (where n is the input)

# # cal time complexity
# remove additive and multiplication constant

total_operation = n

total_operation =  O(n) # order of n  mean it is linear relationship

# if the input increase the time will increase

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# n**2 + 2n +2
#
# n**2 + n
#
# ![image.png](attachment:image.png)
# means the time  is coming from n and n**2 so we will remove the small time
#
# time complexity = O(n**2) # it is Quadratic relation between time and input mean the n=2 is then the  time complexity double it is 4*times

# %% [markdown]
# time complexity of 2nd example
# O(n**2)
# for third O(n)
