# %% [markdown]
# # Type of DS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # array
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# list is the referential array
# we create array and in first arr we give the element and second arr we keep the memory address
#
# by implementing the referential array we solve the problem of homogeneous
#
# ![image.png](attachment:image.png)
#
#
#
#
# ### fixed size (memory waste)
#
# we need to implement the concept of dynamic array (it is concept not dynamic array)
#
# ![image-2.png](attachment:image-2.png)
#
# we have static array with size =1 we can store
# but now i want add more number to the array it will copy the element of first array paste to another and then add second   number
#
# this concept is called as the dyamic array

# %%
import ctypes

def __init__(self):
    self.size = 1
    self.n = 0

    self.A = self.__make_array(self.size)


def __make_array(self,capacity):
    return (capacity*ctypes.py_object)()

# %%
# addition of two numbers
a = 10
b = 10
